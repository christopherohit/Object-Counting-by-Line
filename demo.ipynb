# %%
total_log = []
with open('/mnt/d/docker_volume/room_of_nhanhuynh/ai_butler/Customer_counting/logs/Tam_Ky__ch17_20240515170207_20240515171441.txt','r') as f:
    for line in f:
        total_log.append(line.strip())
for line in total_log:
    frame, track_id, class_id, bbox, conf = line.split('|')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       4         total_log.append(line.strip())
#       5 for line in total_log:
# ----> 6     frame, track_id, class_id, bbox, conf = line.split('|')
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
line.split('|')
# Out:
# ['65',
#  '[          1           2]',
#  '[          0           0]',
#  '[[     382.75      187.72      590.05      646.32]']

# %%
total_log
# Out:
# ['1|[          1]|[          0]|[[     380.88      188.78      589.88      640.01]]|[    0.65081]',
#  '2|[          1]|[          0]|[[      380.9      188.78       590.2      639.61]]|[    0.63548]',
#  '3|[          1]|[          0]|[[      380.8      188.83      590.57      637.98]]|[    0.60505]',
#  '4|[          1]|[          0]|[[     380.85      188.81      590.65      636.86]]|[    0.61106]',
#  '5|[          1]|[          0]|[[     380.88      188.81      590.51      638.04]]|[    0.64398]',
#  '6|[          1]|[          0]|[[     381.12      188.79      590.51      638.44]]|[    0.63743]',
#  '7|[          1]|[          0]|[[     381.38      188.88      590.58      639.13]]|[    0.65307]',
#  '8|[          1]|[          0]|[[     381.31      188.91      590.56      639.11]]|[    0.65215]',
#  '9|[          1]|[          0]|[[     381.79      188.96      590.38      639.66]]|[    0.66626]',
# ...
